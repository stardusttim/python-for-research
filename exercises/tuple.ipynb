# %%
t = 12345, 54321, 'hello!'
print(t)
# Out:
# (12345, 54321, 'hello!')

# %%
u = t, (1, 2, 3, 4, 5)
print(u)
# Out:
# ((12345, 54321, 'hello!'), (1, 2, 3, 4, 5))

# %% [markdown]
# Tuple is immutable

# %%
empty = ()
print(len(empty))
# Out:
# 0

# %%
singleton = 'hello',   # Notice the comma in the end
print(singleton)
string = 'hello'
print(string)
# Out:
# ('hello',)
# hello

# %%
x = 12345
y = 54321
z = 'hello!'
x, y, z = t
print(t)
# Out:
# (12345, 54321, 'hello!')
