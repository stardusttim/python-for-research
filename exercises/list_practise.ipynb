# %%
lst = [1, 2, 3, 4]

# %%
lst.append(5)
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
# must be []
lst.extend([6, 7, 8])
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
lst.insert(len(lst), 9)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# remove the first that is 9 (not the 9th) 
lst.remove(9)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# remove i (0 to len(lst-1))
lst.pop(7)
print(lst)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
lst1 = [i for i in lst]
lst1.clear()
print(lst1)
print(lst)
# Out:
# []
# [1, 2, 3, 4, 5, 6, 7]

# %%
# list.index(x, start,end)
# start and end are optional
lst.index(4, 1, 4)
# Out:
# 3

# %%
lst.count(7)
# Out:
# 1

# %%
lst2 = [1, 4, 2, 3]
lst2.sort()
print(lst2)
# Out:
# [1, 2, 3, 4]

# %%
lst3 = [1, 4, 2, 3]
lst3.reverse()
print(lst3)
# Out:
# [3, 2, 4, 1]

# %%
# for item in lst.copy()
#     ...
##Do not change lst
