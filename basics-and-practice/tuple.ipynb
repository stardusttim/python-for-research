# %%
t = 12345, 54321, 'hello!'
print(t)

# %%
u = t, (1, 2, 3, 4, 5)
print(u)

# %% [markdown]
# Tuple is immutable

# %%
empty = ()
print(len(empty))

# %%
singleton = 'hello',   # Notice the comma in the end
print(singleton)
string = 'hello'
print(string)

# %%
x = 12345
y = 54321
z = 'hello!'
x, y, z = t
print(t)
